# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import cv2
from scipy.ndimage.filters import gaussian_filter
from copy import deepcopy

import os

# %%
def load_fer2013(filename='fer2013/fer2013.csv'):
    df = pd.read_csv(filename, sep=',',header=0)
    images = []
    labels = []
    for each in df['pixels'].tolist():
        pom = np.array(each.split(' '))
        pom = np.reshape(pom, (48,48))
        pom = cv2.normalize(pom.astype('float'), None, 0.0, 1.0, cv2.NORM_MINMAX)
        images.append(pom)
    for each in df['emotion'].tolist():
        labels.append(int(each))
    return images, labels

# %%
'''
FER2013 emotion abels:
0 - Angry
1 - Disgust
2 - Fear
3 - Happy
4 - Sad
5 - Surprise
6 - Neutral
'''
fer_images, fer_labels = load_fer2013()

# %%
plt.imshow(fer_images[10], cmap = 'gray')
plt.show()
print(fer_images[10])
# Out:
# [[ 0.09638554  0.07228916  0.06024096 ...,  0.12449799  0.15261044
#    0.12449799]
#  [ 0.10040161  0.06425703  0.06024096 ...,  0.12449799  0.11646586
#    0.14056225]
#  [ 0.08433735  0.06425703  0.05220884 ...,  0.10843373  0.1124498
#    0.13654618]
#  ...,
#  [ 0.09236948  0.09236948  0.08032129 ...,  0.4497992   0.5060241
#    0.57028112]
#  [ 0.09638554  0.09638554  0.08433735 ...,  0.59437751  0.61445783
#    0.64257028]
#  [ 0.10441767  0.09236948  0.08835341 ...,  0.66666667  0.67068273
#    0.67068273]]

# %%
'''
CC emotion labels:
1 - Angry 45
2 - Contempt 18
3 - Disgust 59
4 - Fear 25
5 - Happy 69
6 - Sadness 28
7 - Surprise 83
'''
def load_cohn_canade(rootdir='Cohn_canade\\extended-cohn-kanade-images\\',
                     rootdir2='Cohn_canade\\Emotion_labels\\Emotion'):
    f_img = []
    f_img_path = []
    for subdir, dirs, files in os.walk(rootdir):
        for file in files:
            f_img_path.append(os.path.join(subdir, file))
            f_img.append(f_img_path[-1].split('\\')[-1].split('.')[0])


    f_lbl = []
    f_lbl_path = []
    for subdir, dirs, files in os.walk(rootdir2):
        for file in files:
            f_lbl_path.append(os.path.join(subdir, file))
            f_lbl.append(f_lbl_path[-1].split('\\')[-1].split('.')[0][:-8])

    label = []
    image = []
    for i in range(len(f_lbl)):
        for j in range(len(f_img)):
            if f_lbl[i] == f_img[j]:
                label.append(int(np.loadtxt(f_lbl_path[i])))
                image.append(cv2.imread(f_img_path[j],0))
    return label, image

# %%
cc_label, cc_image = load_cohn_canade()

# %%
#resized_image = cv2.resize(cc_image[-2], (48, 48))
#rimg = cc_image[101][430:460, 20:450]
#plt.imshow(rimg, cmap = 'gray')
#plt.show()

# %%
# HAAR Cascades
def locate_face(img_list, haar='haarcascade_frontalface_default.xml'):
    face_cascade = cv2.CascadeClassifier(haar)
    ilist = deepcopy(img_list)
    for i in range(len(ilist)):
        ilist[i] = gaussian_filter(ilist[i], 1)
        faces = face_cascade.detectMultiScale(ilist[i], 1.3, 5)
        if len(faces) == 1:
            for (x,y,w,h) in faces:    
                ilist[i] = ilist[i][y:(y+h), x:(x+w)]
                ilist[i] = cv2.resize(ilist[i], (48, 48))
            #plt.imshow(ilist[i], cmap = 'gray')
            #plt.show()
        else:
            print('Either more than 1 or no face detected.', i)
            for (x,y,w,h) in faces:
                cv2.rectangle(ilist[i],(x,y),(x+w,y+h),255,2)
            plt.imshow(ilist[i], cmap = 'gray')
            plt.show()
    return ilist

def floatify(ilist):
    for i in range(len(ilist)):
        ilist[i] = cv2.normalize(ilist[i].astype('float'), None, 0.0, 1.0, cv2.NORM_MINMAX)
    return ilist

image_list = locate_face(cc_image)
image_list = floatify(image_list)
# Out:
# Either more than 1 or no face detected. 134

# %%
plt.imshow(image_list[0], cmap = 'gray')
plt.show()
print(image_list[0])
# Out:
# [[ 0.75113122  0.0678733   0.01809955 ...,  0.05429864  0.85972851  1.        ]
#  [ 0.56561086  0.05882353  0.02262443 ...,  0.00904977  0.69683258
#    0.9321267 ]
#  [ 0.32579186  0.04977376  0.02262443 ...,  0.          0.37556561
#    0.96832579]
#  ...,
#  [ 0.90045249  0.70588235  0.58371041 ...,  0.67873303  0.71040724
#    0.54751131]
#  [ 0.79638009  0.77375566  0.73303167 ...,  0.74660633  0.71945701
#    0.59728507]
#  [ 0.91402715  0.85067873  0.86425339 ...,  0.67420814  0.56561086
#    0.58823529]]
